# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from keras.models import *
from keras.layers import *
from keras.callbacks import *

# %%
data=pd.read_csv(r"C:\Users\deepa\Downloads\archive (4)\webtraffic.csv")

# %%
data.shape
# Out:
# (4896, 2)

# %%
data.head()
# Out:
#    Hour Index    Sessions
# 0           0  1418159421
# 1           1  1113769116
# 2           2   919158921
# 3           3   822352824
# 4           4   735526737

# %%
sessions = data['Sessions'].values
ar = np.arange(len(sessions))
plt.figure(figsize = (22,10))
plt.plot(ar, sessions, 'r')
plt.show()

# %%
sample = sessions[:168]
ar = np.arange(len(sample))
plt.figure(figsize = (22,10))
plt.plot(ar, sample, 'r')
plt.show()

# %%
def prepare_data(seq, num):
    x = []
    y = []
    for i in range(0, (len(seq)- num), 1):
        input_ = seq[i:i+num]
        output = seq[i+num]
        
        x.append(input_)
        y.append(output)
    
    return np.array(x), np.array(y)

# %%
num = 168
x,y = prepare_data(sessions, num)
print(len(x))
# Out:
# 4728

# %%
ind = int(0.9*len(x))

# prepare training and test data
X_train = x[:ind]
y_train = y[:ind]

X_test = x[ind:]
y_test = y[ind:]

# %%
X_scaler = StandardScaler()
X_train = X_scaler.fit_transform(X_train)
X_test = X_scaler.fit_transform(X_test)

# %%
y_train = y_train.reshape(len(y_train), 1)
y_test = y_test.reshape(len(y_test), 1)

# %%
y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train)[:, 0]
y_test = y_scaler.fit_transform(y_test)[:, 0]

# %%
X_train= X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test= X_test.reshape(X_test.shape[0],X_test.shape[1],1)
print(X_train.shape)
# Out:
# (4255, 168, 1)

# %%
model = Sequential()
model.add(LSTM(128, input_shape = (168,1)))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 74881 (292.50 KB)
# Trainable params: 74881 (292.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'mse', optimizer = 'adam')
mc = ModelCheckpoint('best_model.hdf5', monitor = 'val_loss', verbose = 1, save_best_only = True, mode = min)
# train the model

history = model.fit(X_train, y_train, epochs = 30, batch_size = 32,
                   validation_data = (X_test, y_test), callbacks = [mc])
# Out:
# WARNING:tensorflow:ModelCheckpoint mode <built-in function min> is unknown, fallback to auto mode.
# Epoch 1/30
# 133/133 [==============================] - ETA: 0s - loss: 0.1573
# Epoch 1: val_loss improved from inf to 0.05751, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 75ms/step - loss: 0.1573 - val_loss: 0.0575
# Epoch 2/30
#   2/133 [..............................] - ETA: 8s - loss: 0.0404
# C:\Users\deepa\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 133/133 [==============================] - ETA: 0s - loss: 0.0388
# Epoch 2: val_loss improved from 0.05751 to 0.04096, saving model to best_model.hdf5
# 133/133 [==============================] - 9s 68ms/step - loss: 0.0388 - val_loss: 0.0410
# Epoch 3/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 3: val_loss did not improve from 0.04096
# 133/133 [==============================] - 13s 95ms/step - loss: 0.0357 - val_loss: 0.0426
# Epoch 4/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 4: val_loss did not improve from 0.04096
# 133/133 [==============================] - 12s 94ms/step - loss: 0.0305 - val_loss: 0.0445
# Epoch 5/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 5: val_loss did not improve from 0.04096
# 133/133 [==============================] - 12s 91ms/step - loss: 0.0302 - val_loss: 0.0410
# Epoch 6/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 6: val_loss improved from 0.04096 to 0.03617, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 94ms/step - loss: 0.0301 - val_loss: 0.0362
# Epoch 7/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 7: val_loss did not improve from 0.03617
# 133/133 [==============================] - 12s 90ms/step - loss: 0.0282 - val_loss: 0.0403
# Epoch 8/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0284
# Epoch 8: val_loss did not improve from 0.03617
# 133/133 [==============================] - 11s 85ms/step - loss: 0.0284 - val_loss: 0.0386
# Epoch 9/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0252
# Epoch 9: val_loss improved from 0.03617 to 0.03371, saving model to best_model.hdf5
# 133/133 [==============================] - 11s 85ms/step - loss: 0.0252 - val_loss: 0.0337
# Epoch 10/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 10: val_loss improved from 0.03371 to 0.03257, saving model to best_model.hdf5
# 133/133 [==============================] - 11s 86ms/step - loss: 0.0248 - val_loss: 0.0326
# Epoch 11/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 11: val_loss improved from 0.03257 to 0.02993, saving model to best_model.hdf5
# 133/133 [==============================] - 11s 85ms/step - loss: 0.0213 - val_loss: 0.0299
# Epoch 12/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 12: val_loss did not improve from 0.02993
# 133/133 [==============================] - 11s 83ms/step - loss: 0.0208 - val_loss: 0.0339
# Epoch 13/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 13: val_loss did not improve from 0.02993
# 133/133 [==============================] - 11s 83ms/step - loss: 0.0204 - val_loss: 0.0308
# Epoch 14/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0182
# Epoch 14: val_loss improved from 0.02993 to 0.02923, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 87ms/step - loss: 0.0182 - val_loss: 0.0292
# Epoch 15/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 15: val_loss improved from 0.02923 to 0.02839, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0179 - val_loss: 0.0284
# Epoch 16/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 16: val_loss did not improve from 0.02839
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0187 - val_loss: 0.0299
# Epoch 17/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 17: val_loss improved from 0.02839 to 0.02662, saving model to best_model.hdf5
# 133/133 [==============================] - 11s 85ms/step - loss: 0.0181 - val_loss: 0.0266
# Epoch 18/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 18: val_loss did not improve from 0.02662
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0167 - val_loss: 0.0304
# Epoch 19/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 19: val_loss improved from 0.02662 to 0.02528, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 93ms/step - loss: 0.0164 - val_loss: 0.0253
# Epoch 20/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 20: val_loss did not improve from 0.02528
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0171 - val_loss: 0.0288
# Epoch 21/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 21: val_loss did not improve from 0.02528
# 133/133 [==============================] - 12s 90ms/step - loss: 0.0156 - val_loss: 0.0307
# Epoch 22/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 22: val_loss improved from 0.02528 to 0.02438, saving model to best_model.hdf5
# 133/133 [==============================] - 11s 86ms/step - loss: 0.0159 - val_loss: 0.0244
# Epoch 23/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 23: val_loss did not improve from 0.02438
# 133/133 [==============================] - 12s 90ms/step - loss: 0.0161 - val_loss: 0.0293
# Epoch 24/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 24: val_loss improved from 0.02438 to 0.02406, saving model to best_model.hdf5
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0164 - val_loss: 0.0241
# Epoch 25/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 25: val_loss did not improve from 0.02406
# 133/133 [==============================] - 12s 87ms/step - loss: 0.0157 - val_loss: 0.0279
# Epoch 26/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 26: val_loss did not improve from 0.02406
# 133/133 [==============================] - 12s 87ms/step - loss: 0.0151 - val_loss: 0.0286
# Epoch 27/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 27: val_loss did not improve from 0.02406
# 133/133 [==============================] - 12s 88ms/step - loss: 0.0152 - val_loss: 0.0271
# Epoch 28/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 28: val_loss did not improve from 0.02406
# 133/133 [==============================] - 12s 87ms/step - loss: 0.0155 - val_loss: 0.0266
# Epoch 29/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 29: val_loss did not improve from 0.02406
# 133/133 [==============================] - 12s 89ms/step - loss: 0.0145 - val_loss: 0.0283
# Epoch 30/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 30: val_loss did not improve from 0.02406
# 133/133 [==============================] - 11s 83ms/step - loss: 0.0153 - val_loss: 0.0285

# %%
model.load_weights('best_model.hdf5')

# %%
mse = model.evaluate(X_train, y_train)
print("Mean Square Error:",mse)
# Out:
# 133/133 [==============================] - 4s 28ms/step - loss: 0.0149
# Mean Square Error: 0.014872662723064423

# %%
def Forecast(X_test, no_of_pred, ind):
    predictions = []
    temp = X_test[ind]
    for i in range(no_of_pred):
        pred = model.predict(temp.reshape(1,-1,1))[0][0]
        temp = np.insert(temp, len(temp), pred)
        predictions.append(pred)
        temp = temp[1:]
    return predictions

# %%
no_of_pred = 24
ind = 72
y_pred = Forecast(X_test, no_of_pred, ind)
y_true = y_test[ind:ind+(no_of_pred)]
# Out:
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
def plot(y_true,y_pred):
  ar = np.arange(len(y_true))
  plt.figure(figsize=(22,10))
  plt.plot(ar, y_true,'r')
  plt.plot(ar, y_pred,'y')
  plt.show()

# %%
plot(y_true, y_pred)
